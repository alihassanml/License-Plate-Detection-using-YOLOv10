# %%
import os
os.chdir('/content/drive/MyDrive/Yolo Detection')

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# fatal: destination path 'yolov10' already exists and is not an empty directory.

# %%
# Data Set Downlaod 
# !kaggle datasets download -d alihassanml/yolo-number-plates
import zipfile
zipfile.ZipFile('yolodataset.zip').extractall('./yolov10/datasets')

# %%
os.chdir('yolov10')

# %%
# !pip install -e .

# %%
# !pip install -r requirements.txt

# %%
# !pip install ultralytics
from ultralytics import YOLOv10

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10n.pt
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10s.pt
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10m.pt
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10b.pt
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10x.pt
# Downloaded /content/drive/MyDrive/Yolo Detection/yolov10/weights/yolov10l.pt

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=yolov10n.pt data=custome_data.yaml

# %%
# !yolo task=detect mode=predict  model=runs/detect/train/weights/best.pt source=video.mp4
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 (no detections), 259.3ms
# video 1/1 (frame 2/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 (no detections), 263.0ms
# video 1/1 (frame 3/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 (no detections), 251.4ms
# video 1/1 (frame 4/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 1 license_plate, 253.4ms
# video 1/1 (frame 5/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 1 license_plate, 265.7ms
# video 1/1 (frame 6/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 (no detections), 233.0ms
# video 1/1 (frame 7/3600) /content/drive/MyDrive/Yolo Detection/yolov10/video.mp4: 384x640 (no detections), 214.7ms
# ...
